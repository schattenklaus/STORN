# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import edward as ed
from pandas import read_csv
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM , Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from edward.models import Bernoulli, Normal
from edward.util import Progbar
from tensorflow.python.framework import ops      #resets TF Graph to set the seed
ops.reset_default_graph()
sess = tf.InteractiveSession()
# Out:
# Using TensorFlow backend.

# %%
run=1
np.random.seed(7)
plt.style.use(['seaborn-darkgrid'])
batch_size = 2
look_back = 9
epochs=100
np.random.seed(7)
d=2  # latent dim

# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
if run==1:
   dataset = np.cos(np.arange(1000)*(20*np.pi/1000))[:,None]
   plt.plot(dataset)
   #scaler = MinMaxScaler(feature_range=(0, 1))
#   dataset = scaler.fit_transform(dataset)
   print "Dataset", run
elif run==2:
   dataset = read_csv('international-airline-passengers.csv', usecols=[1], engine='python', skipfooter=3)
   dataset = dataset.values
   dataset = dataset.astype('float32')
   print "Dataset", run
   plt.plot(dataset)
   scaler = MinMaxScaler(feature_range=(0, 1))
   dataset = scaler.fit_transform(dataset)


train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainY= np.reshape(trainY, (trainY.shape[0], 1))
testY=np.reshape(testY, (testY.shape[0], 1))

trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

plt.show()
# Out:
# Dataset 1

# %%
# MODEL
# Define a subgraph of the full model, corresponding to a minibatch of
# size M.
z = Normal(loc=tf.zeros([batch_size, d,1]), scale=tf.ones([batch_size, d,1]))
hidden = Dense(2)(z.value())
x = LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True, unroll=True)(hidden)

# %%
x_ph = tf.placeholder(tf.int32, [batch_size, look_back,1])
hidden1 = LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True, unroll=True)
hidden = Dense(2)(hidden1)
qz = Normal(loc=Dense(d)(hidden),
            scale=Dense(d)(hidden))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-4844debc6e9b> in <module>()
#       1 x_ph = tf.placeholder(tf.int32, [batch_size, look_back,1])
#       2 hidden1 = LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True, unroll=True)
# ----> 3 hidden = Dense(2)(hidden1)
#       4 qz = Normal(loc=Dense(d)(hidden),
#       5             scale=Dense(d)(hidden))
#
# /home/steffen/anaconda2/lib/python2.7/site-packages/keras/engine/topology.pyc in __call__(self, inputs, **kwargs)
#     539                 # Raise exceptions in case the input is not compatible
#     540                 # with the input_spec specified in the layer constructor.
# --> 541                 self.assert_input_compatibility(inputs)
#     542
#     543                 # Collect input shapes to build layer.
#
# /home/steffen/anaconda2/lib/python2.7/site-packages/keras/engine/topology.pyc in assert_input_compatibility(self, inputs)
#     448                                      str(K.ndim(x)))
#     449             if spec.min_ndim is not None:
# --> 450                 ndim = K.ndim(x)
#     451                 if ndim is not None and ndim < spec.min_ndim:
#     452                     raise ValueError('Input ' + str(input_index) +
#
# /home/steffen/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in ndim(x)
#     477     ```
#     478     """
# --> 479     dims = x.get_shape()._dims
#     480     if dims is not None:
#     481         return len(dims)
#
# AttributeError: 'LSTM' object has no attribute 'get_shape'

# %%
inference = ed.KLqp({z: qz}, data={x: x_ph})
optimizer = tf.train.RMSPropOptimizer(0.01, epsilon=1.0)
inference.initialize(optimizer=optimizer)
